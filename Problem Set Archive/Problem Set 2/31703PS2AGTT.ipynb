# %% [markdown]
# # ECON 31703 Problem Set 2 - Arjun Gopinath and Tugce Turk (Question 1)

# %%
# Standard Python Imports

import numpy as np
import pandas as pd
from numba import njit, jit
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rc
import statsmodels.api as sm
from scipy.stats import norm, zscore
import scipy as sp
from numpy import random, linalg
from scipy import sparse, stats
import itertools as it
from sklearn.preprocessing import StandardScaler as scaler
from sklearn.linear_model import Lasso
import cProfile
import warnings

warnings.filterwarnings("ignore")

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.preamble'] = [
    r'\usepackage{amssymb}',
    r'\usepackage{amsmath}',
    r'\usepackage{xcolor}',
    r'\renewcommand*\familydefault{\sfdefault}']
matplotlib.rcParams['pgf.texsystem'] = 'pdflatex'
matplotlib.rcParams['pgf.preamble']  = [
    r'\usepackage[utf8x]{inputenc}',
    r'\usepackage{amssymb}',
    r'\usepackage[T1]{fontenc}',
    r'\usepackage{amsmath}',
    r'\usepackage{sansmath}']

from IPython.display import set_matplotlib_formats
# %matplotlib inline
set_matplotlib_formats('svg')

inv, ax, norm = np.linalg.inv, np.newaxis, np.linalg.norm
randint = np.random.randint

# %%
# Import functions from helper file.

from LASSOHelperAGTT import simulate_data, lasso_objective, lasso_cdg, lasso_wrapper_sequential, lasso_wrapper_parallel

# %%
# Configure dataset size
N_obs = 200
N_param = 120

# Configure number of parameters to be set to zero (randomly)
n_0 = 70

# Simulate data used in exercise
Y, X = simulate_data(N_obs=N_obs, N_param=N_param, n_0=n_0)

# %% [markdown]
# ## Exercise 1 - Coordinate Gradient Descent in LASSO
#
# ### Part A: LASSO Objective Function
#
# We have coded this in `lasso_objective`.
#
# ### Part B: Cyclic Coordinate Gradient Descent
#
# We have coded this in `lasso_cdg`.

# %%
cProfile.run('lasso_cdg(b_start=np.zeros([N_param, 1]), y=Y, X=X, lmbda=0.1)')
# Out:
#          12138 function calls (12058 primitive calls) in 0.671 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        40    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(append)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        80    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(norm)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ravel)
#         2    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(sum)
#         1    0.001    0.001    0.671    0.671 <string>:1(<module>)
#         1    0.627    0.627    0.670    0.670 LASSOHelperAGTT.py:132(lasso_cdg)
#        40    0.000    0.000    0.006    0.000 LASSOHelperAGTT.py:189(<lambda>)
#        36    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:192(<lambda>)
#         1    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:216(<listcomp>)
#        40    0.005    0.000    0.006    0.000 LASSOHelperAGTT.py:64(lasso_objective)
#      4760    0.021    0.000    0.021    0.000 LASSOHelperAGTT.py:87(dual_sol)
#        80    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#        95    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         5    0.000    0.000    0.001    0.000 _methods.py:134(_mean)
#         4    0.002    0.000    0.003    0.001 _methods.py:167(_var)
#         4    0.000    0.000    0.003    0.001 _methods.py:215(_std)
#        80    0.000    0.000    0.001    0.000 _methods.py:28(_amax)
#        40    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         9    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:1693(ravel)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#         2    0.000    0.000    0.001    0.000 fromnumeric.py:2092(sum)
#         2    0.000    0.000    0.001    0.000 fromnumeric.py:73(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#        40    0.000    0.000    0.000    0.000 function_base.py:4636(_append_dispatcher)
#        40    0.000    0.000    0.001    0.000 function_base.py:4640(append)
#        80    0.000    0.000    0.000    0.000 linalg.py:2312(_norm_dispatcher)
#        80    0.001    0.000    0.002    0.000 linalg.py:2316(norm)
#        40    0.000    0.000    0.000    0.000 multiarray.py:145(concatenate)
#        40    0.000    0.000    0.000    0.000 multiarray.py:707(dot)
#         2    0.001    0.000    0.003    0.002 stats.py:2349(zscore)
#         2    0.000    0.000    0.001    0.001 stats.py:248(_contains_nan)
#         1    0.000    0.000    0.671    0.671 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        68    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        98    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       160    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        37    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       175    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#   242/162    0.001    0.000    0.004    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       160    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        41    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       120    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        80    0.000    0.000    0.001    0.000 {method 'max' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.001    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        40    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       216    0.003    0.000    0.003    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      4760    0.007    0.000    0.007    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.003    0.001 {method 'std' of 'numpy.ndarray' objects}
#        40    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}

# %% [markdown]
# ### Part C: Active Set Strategy
#
# We have coded this in `lasso_cdg` by adding options `active_set` and `active_set_strategy`. Setting `active_set` to True (when the default is false) and specifying the number of iterations after which all $p$ parameters are updated allows this function to implement the Active Set strategy in place of the regular CDG.

# %%
cProfile.run('lasso_cdg(b_start=np.zeros([N_param, 1]), y=Y, X=X, lmbda=0.1, active_set=True)')
# Out:
#          5235 function calls (5157 primitive calls) in 0.230 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        39    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(append)
#        39    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#        39    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        78    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(norm)
#        39    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ravel)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#        35    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(where)
#         1    0.000    0.000    0.230    0.230 <string>:1(<module>)
#         1    0.206    0.206    0.229    0.229 LASSOHelperAGTT.py:132(lasso_cdg)
#        39    0.000    0.000    0.007    0.000 LASSOHelperAGTT.py:189(<lambda>)
#        35    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:197(<lambda>)
#         1    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:216(<listcomp>)
#        39    0.005    0.000    0.007    0.000 LASSOHelperAGTT.py:64(lasso_objective)
#      1304    0.007    0.000    0.007    0.000 LASSOHelperAGTT.py:87(dual_sol)
#        78    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#        93    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         5    0.000    0.000    0.001    0.000 _methods.py:134(_mean)
#         4    0.002    0.000    0.002    0.001 _methods.py:167(_var)
#         4    0.000    0.000    0.002    0.001 _methods.py:215(_std)
#        78    0.000    0.000    0.001    0.000 _methods.py:28(_amax)
#        39    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         9    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#        39    0.000    0.000    0.000    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#        39    0.000    0.000    0.000    0.000 fromnumeric.py:1693(ravel)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2092(sum)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#        39    0.000    0.000    0.000    0.000 function_base.py:4636(_append_dispatcher)
#        39    0.000    0.000    0.001    0.000 function_base.py:4640(append)
#        78    0.000    0.000    0.000    0.000 linalg.py:2312(_norm_dispatcher)
#        78    0.001    0.000    0.003    0.000 linalg.py:2316(norm)
#        39    0.000    0.000    0.000    0.000 multiarray.py:145(concatenate)
#        35    0.000    0.000    0.000    0.000 multiarray.py:312(where)
#        39    0.000    0.000    0.000    0.000 multiarray.py:707(dot)
#         2    0.000    0.000    0.001    0.001 stats.py:2349(zscore)
#         2    0.000    0.000    0.000    0.000 stats.py:248(_contains_nan)
#         1    0.000    0.000    0.230    0.230 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        67    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        96    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       156    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       171    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#   271/193    0.001    0.000    0.005    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       156    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        40    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       117    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        78    0.000    0.000    0.001    0.000 {method 'max' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.001    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        39    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       211    0.003    0.000    0.003    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1304    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.002    0.001 {method 'std' of 'numpy.ndarray' objects}
#        39    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}

# %% [markdown]
# ### Part D: Computing $\lambda_{\max}$
# We have coded this in `lambda_zero`.
#
# ### Part E: SAFE Strategy
#
# We have coded this in `lasso_cdg` by adding options `safe`. Setting `safe` to True (when the default is false) allows this function to implement the SAFE strategy along with the Active Set strategy.

# %%
cProfile.run('lasso_cdg(b_start=np.zeros([N_param, 1]), y=Y, X=X, lmbda=0.1, active_set=True, safe=True)')
# Out:
#          5286 function calls (5207 primitive calls) in 0.195 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amax)
#        39    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(append)
#        39    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        80    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(norm)
#        39    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ravel)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#        36    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(where)
#         1    0.000    0.000    0.194    0.194 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:106(lambda_zero)
#         1    0.173    0.173    0.194    0.194 LASSOHelperAGTT.py:132(lasso_cdg)
#        39    0.000    0.000    0.007    0.000 LASSOHelperAGTT.py:189(<lambda>)
#        35    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:197(<lambda>)
#         1    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:216(<listcomp>)
#        39    0.005    0.000    0.007    0.000 LASSOHelperAGTT.py:64(lasso_objective)
#      1304    0.006    0.000    0.006    0.000 LASSOHelperAGTT.py:87(dual_sol)
#        80    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#        94    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         6    0.000    0.000    0.001    0.000 _methods.py:134(_mean)
#         4    0.001    0.000    0.001    0.000 _methods.py:167(_var)
#         4    0.000    0.000    0.001    0.000 _methods.py:215(_std)
#        78    0.000    0.000    0.001    0.000 _methods.py:28(_amax)
#        39    0.000    0.000    0.000    0.000 _methods.py:36(_sum)
#         2    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#        10    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#        39    0.000    0.000    0.000    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#        39    0.000    0.000    0.000    0.000 fromnumeric.py:1693(ravel)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2092(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2546(_amax_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2551(amax)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#        39    0.000    0.000    0.000    0.000 function_base.py:4636(_append_dispatcher)
#        39    0.000    0.000    0.001    0.000 function_base.py:4640(append)
#         1    0.000    0.000    0.000    0.000 linalg.py:121(isComplexType)
#        80    0.000    0.000    0.000    0.000 linalg.py:2312(_norm_dispatcher)
#        80    0.001    0.000    0.003    0.000 linalg.py:2316(norm)
#        39    0.000    0.000    0.000    0.000 multiarray.py:145(concatenate)
#        36    0.000    0.000    0.000    0.000 multiarray.py:312(where)
#        40    0.000    0.000    0.000    0.000 multiarray.py:707(dot)
#         2    0.000    0.000    0.001    0.001 stats.py:2349(zscore)
#         2    0.000    0.000    0.000    0.000 stats.py:248(_contains_nan)
#         1    0.000    0.000    0.195    0.195 {built-in method builtins.exec}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       101    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       157    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       174    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#   276/197    0.001    0.000    0.005    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       156    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        40    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       117    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        78    0.000    0.000    0.001    0.000 {method 'max' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.001    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        40    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       215    0.003    0.000    0.003    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1304    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.001    0.000 {method 'std' of 'numpy.ndarray' objects}
#        39    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}

# %% [markdown]
# The following table shows the relative time taken to compute the LASSO estimate under the three provided optimization strategies.
#
# |  Optimization | Cyclic Coordinate Gradient Descent | CDG +  Active Set | CDG +  Active Set + SAFE |
# |:-------------:|:----------------------------------:|:-----------------:|:------------------------:|
# | Relative Time |                  1                 |       0.3427      |          0.2906          |
#
# Clearly, running the active-set and SAFE configurations together provide a significant reduction in the time taken to compute the LASSO estimate.
#
# ### Part F: Wrapping around multiple $\lambda$ values : Sequential loop, common starting value

# %%
cProfile.run('lasso_wrapper_sequential(b_start=np.zeros([N_param, 1]), y=Y, X=X, standardized=False, num_lambda=100, min_factor=0.001)')
# Out:
#          3647142 function calls (3611741 primitive calls) in 161.825 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       101    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(amax)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#     17649    0.022    0.000    0.366    0.000 <__array_function__ internals>:2(append)
#     17649    0.022    0.000    0.106    0.000 <__array_function__ internals>:2(concatenate)
#     17749    0.034    0.000    0.108    0.000 <__array_function__ internals>:2(dot)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(flipud)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#     35498    0.052    0.000    1.050    0.000 <__array_function__ internals>:2(norm)
#     17649    0.021    0.000    0.138    0.000 <__array_function__ internals>:2(ravel)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#       202    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(sum)
#     15941    0.019    0.000    0.101    0.000 <__array_function__ internals>:2(where)
#         1    0.000    0.000  161.825  161.825 <string>:1(<module>)
#       101    0.014    0.000    0.019    0.000 LASSOHelperAGTT.py:106(lambda_zero)
#       100  146.998    1.470  161.815    1.618 LASSOHelperAGTT.py:132(lasso_cdg)
#     17649    0.014    0.000    2.627    0.000 LASSOHelperAGTT.py:189(<lambda>)
#     15841    0.093    0.000    0.194    0.000 LASSOHelperAGTT.py:197(<lambda>)
#       100    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:216(<listcomp>)
#         1    0.007    0.007  161.824  161.824 LASSOHelperAGTT.py:269(lasso_wrapper_sequential)
#         1    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:312(<listcomp>)
#     17649    1.967    0.000    2.613    0.000 LASSOHelperAGTT.py:64(lasso_objective)
#   1259306    9.208    0.000    9.208    0.000 LASSOHelperAGTT.py:87(dual_sol)
#     35498    0.017    0.000    0.049    0.000 _asarray.py:16(asarray)
#     36910    0.015    0.000    0.032    0.000 _asarray.py:88(asanyarray)
#       603    0.005    0.000    0.013    0.000 _methods.py:134(_mean)
#       402    0.018    0.000    0.029    0.000 _methods.py:167(_var)
#       402    0.002    0.000    0.031    0.000 _methods.py:215(_std)
#     35298    0.020    0.000    0.198    0.000 _methods.py:28(_amax)
#     17649    0.013    0.000    0.178    0.000 _methods.py:36(_sum)
#         1    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#       201    0.000    0.000    0.001    0.000 _methods.py:47(_all)
#      1005    0.002    0.000    0.002    0.000 _methods.py:50(_count_reduce_items)
#       404    0.001    0.000    0.001    0.000 _ufunc_config.py:139(geterr)
#       404    0.001    0.000    0.003    0.000 _ufunc_config.py:39(seterr)
#       202    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#       202    0.000    0.000    0.002    0.000 _ufunc_config.py:441(__enter__)
#       202    0.000    0.000    0.001    0.000 _ufunc_config.py:446(__exit__)
#     17649    0.004    0.000    0.004    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#     17649    0.043    0.000    0.102    0.000 fromnumeric.py:1693(ravel)
#       202    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#       202    0.000    0.000    0.005    0.000 fromnumeric.py:2092(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2232(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2236(any)
#       101    0.000    0.000    0.000    0.000 fromnumeric.py:2546(_amax_dispatcher)
#       101    0.000    0.000    0.002    0.000 fromnumeric.py:2551(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#       304    0.001    0.000    0.005    0.000 fromnumeric.py:73(_wrapreduction)
#       304    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:21(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:26(linspace)
#     17649    0.004    0.000    0.004    0.000 function_base.py:4636(_append_dispatcher)
#     17649    0.064    0.000    0.326    0.000 function_base.py:4640(append)
#       100    0.000    0.000    0.000    0.000 linalg.py:121(isComplexType)
#     35498    0.009    0.000    0.009    0.000 linalg.py:2312(_norm_dispatcher)
#     35498    0.395    0.000    0.953    0.000 linalg.py:2316(norm)
#     17649    0.004    0.000    0.004    0.000 multiarray.py:145(concatenate)
#     15941    0.004    0.000    0.004    0.000 multiarray.py:312(where)
#         1    0.000    0.000    0.000    0.000 multiarray.py:635(result_type)
#     17749    0.005    0.000    0.005    0.000 multiarray.py:707(dot)
#         1    0.000    0.000    0.000    0.000 numeric.py:1786(isscalar)
#       202    0.007    0.000    0.038    0.000 stats.py:2349(zscore)
#       202    0.002    0.000    0.011    0.000 stats.py:248(_contains_nan)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:44(_flip_dispatcher)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:99(flipud)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000  161.825  161.825 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       501    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#     20766    0.013    0.000    0.013    0.000 {built-in method builtins.isinstance}
#     37608    0.014    0.000    0.014    0.000 {built-in method builtins.issubclass}
#     70696    0.008    0.000    0.008    0.000 {built-in method builtins.len}
#       402    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       101    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#     72408    0.049    0.000    0.049    0.000 {built-in method numpy.array}
# 122443/87042    0.290    0.000    1.483    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     70596    0.029    0.000    0.029    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       808    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#       404    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#     17650    0.028    0.000    0.028    0.000 {built-in method numpy.zeros}
#       201    0.000    0.000    0.001    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#     53347    0.011    0.000    0.011    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       304    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#     35298    0.044    0.000    0.242    0.000 {method 'max' of 'numpy.ndarray' objects}
#       603    0.001    0.000    0.014    0.000 {method 'mean' of 'numpy.ndarray' objects}
#       202    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#     17749    0.034    0.000    0.034    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     90257    0.577    0.000    0.577    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   1259307    1.584    0.000    1.584    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#       402    0.000    0.000    0.031    0.000 {method 'std' of 'numpy.ndarray' objects}
#     17649    0.032    0.000    0.210    0.000 {method 'sum' of 'numpy.ndarray' objects}

# %% [markdown]
# ### Part F: Wrapping around multiple $\lambda$ values : Sequential loop, warm start

# %%
cProfile.run('lasso_wrapper_sequential(b_start=np.zeros([N_param, 1]), y=Y, X=X, standardized=False, num_lambda=100, min_factor=0.001, warm_start=True)')
# Out:
#          3168630 function calls (3137785 primitive calls) in 152.363 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       101    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(amax)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#     15371    0.023    0.000    0.356    0.000 <__array_function__ internals>:2(append)
#     15371    0.021    0.000    0.105    0.000 <__array_function__ internals>:2(concatenate)
#     15471    0.034    0.000    0.108    0.000 <__array_function__ internals>:2(dot)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(flipud)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#     30942    0.052    0.000    1.048    0.000 <__array_function__ internals>:2(norm)
#     15371    0.020    0.000    0.132    0.000 <__array_function__ internals>:2(ravel)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#       202    0.000    0.000    0.007    0.000 <__array_function__ internals>:2(sum)
#     13887    0.019    0.000    0.099    0.000 <__array_function__ internals>:2(where)
#         1    0.001    0.001  152.363  152.363 <string>:1(<module>)
#       101    0.016    0.000    0.025    0.000 LASSOHelperAGTT.py:106(lambda_zero)
#       100  137.946    1.379  152.348    1.523 LASSOHelperAGTT.py:132(lasso_cdg)
#     15371    0.015    0.000    2.460    0.000 LASSOHelperAGTT.py:189(<lambda>)
#     13787    0.090    0.000    0.189    0.000 LASSOHelperAGTT.py:197(<lambda>)
#       100    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:216(<listcomp>)
#         1    0.008    0.008  152.362  152.362 LASSOHelperAGTT.py:269(lasso_wrapper_sequential)
#         1    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:312(<listcomp>)
#     15371    1.822    0.000    2.445    0.000 LASSOHelperAGTT.py:64(lasso_objective)
#   1091359    9.019    0.000    9.019    0.000 LASSOHelperAGTT.py:87(dual_sol)
#     30942    0.016    0.000    0.049    0.000 _asarray.py:16(asarray)
#     32354    0.015    0.000    0.031    0.000 _asarray.py:88(asanyarray)
#       603    0.006    0.000    0.017    0.000 _methods.py:134(_mean)
#       402    0.024    0.000    0.037    0.000 _methods.py:167(_var)
#       402    0.003    0.000    0.040    0.000 _methods.py:215(_std)
#     30742    0.020    0.000    0.193    0.000 _methods.py:28(_amax)
#     15371    0.013    0.000    0.170    0.000 _methods.py:36(_sum)
#         1    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#       201    0.000    0.000    0.001    0.000 _methods.py:47(_all)
#      1005    0.002    0.000    0.002    0.000 _methods.py:50(_count_reduce_items)
#       404    0.001    0.000    0.001    0.000 _ufunc_config.py:139(geterr)
#       404    0.002    0.000    0.004    0.000 _ufunc_config.py:39(seterr)
#       202    0.000    0.000    0.001    0.000 _ufunc_config.py:437(__init__)
#       202    0.001    0.000    0.003    0.000 _ufunc_config.py:441(__enter__)
#       202    0.000    0.000    0.002    0.000 _ufunc_config.py:446(__exit__)
#     15371    0.004    0.000    0.004    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#     15371    0.041    0.000    0.098    0.000 fromnumeric.py:1693(ravel)
#       202    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#       202    0.001    0.000    0.006    0.000 fromnumeric.py:2092(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2232(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2236(any)
#       101    0.000    0.000    0.000    0.000 fromnumeric.py:2546(_amax_dispatcher)
#       101    0.000    0.000    0.002    0.000 fromnumeric.py:2551(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#       304    0.001    0.000    0.007    0.000 fromnumeric.py:73(_wrapreduction)
#       304    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:21(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:26(linspace)
#     15371    0.004    0.000    0.004    0.000 function_base.py:4636(_append_dispatcher)
#     15371    0.062    0.000    0.316    0.000 function_base.py:4640(append)
#       100    0.000    0.000    0.000    0.000 linalg.py:121(isComplexType)
#     30942    0.009    0.000    0.009    0.000 linalg.py:2312(_norm_dispatcher)
#     30942    0.395    0.000    0.942    0.000 linalg.py:2316(norm)
#     15371    0.004    0.000    0.004    0.000 multiarray.py:145(concatenate)
#     13887    0.003    0.000    0.003    0.000 multiarray.py:312(where)
#         1    0.000    0.000    0.000    0.000 multiarray.py:635(result_type)
#     15471    0.005    0.000    0.005    0.000 multiarray.py:707(dot)
#         1    0.000    0.000    0.000    0.000 numeric.py:1786(isscalar)
#       202    0.010    0.000    0.051    0.000 stats.py:2349(zscore)
#       202    0.003    0.000    0.015    0.000 stats.py:248(_contains_nan)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:44(_flip_dispatcher)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:99(flipud)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000  152.363  152.363 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       501    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#     18488    0.013    0.000    0.013    0.000 {built-in method builtins.isinstance}
#     33052    0.014    0.000    0.014    0.000 {built-in method builtins.issubclass}
#     61584    0.008    0.000    0.008    0.000 {built-in method builtins.len}
#       402    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       101    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#     63296    0.049    0.000    0.049    0.000 {built-in method numpy.array}
# 106721/75876    0.295    0.000    1.470    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     61484    0.028    0.000    0.028    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       808    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#       404    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#     15372    0.027    0.000    0.027    0.000 {built-in method numpy.zeros}
#       201    0.000    0.000    0.001    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#     46513    0.011    0.000    0.011    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       304    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#     30742    0.044    0.000    0.237    0.000 {method 'max' of 'numpy.ndarray' objects}
#       603    0.001    0.000    0.018    0.000 {method 'mean' of 'numpy.ndarray' objects}
#       202    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#     15471    0.033    0.000    0.033    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     78867    0.567    0.000    0.567    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   1091360    1.509    0.000    1.509    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#       402    0.001    0.000    0.041    0.000 {method 'std' of 'numpy.ndarray' objects}
#     15371    0.031    0.000    0.201    0.000 {method 'sum' of 'numpy.ndarray' objects}

# %%
cProfile.run('lasso_wrapper_parallel(b_start=np.zeros([N_param, 1]), y=Y, X=X, standardized=False, num_lambda=100, min_factor=0.001)')
# Out:
#          51628 function calls (48335 primitive calls) in 48.670 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amax)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(any)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(flipud)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(linspace)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#     39/37    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#       3/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#        16    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:269(_module_repr)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#        36    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#       2/1    0.000    0.000    0.006    0.006 <frozen importlib._bootstrap>:663(_load_unlocked)
#        16    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:710(module_repr)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#       2/1    0.000    0.000    0.007    0.007 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#       2/1    0.000    0.000    0.007    0.007 <frozen importlib._bootstrap>:978(_find_and_load)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:719(create_module)
#       2/1    0.000    0.000    0.006    0.006 <frozen importlib._bootstrap_external>:722(exec_module)
#         6    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         2    0.000    0.000    0.005    0.003 <frozen importlib._bootstrap_external>:793(get_code)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:909(get_filename)
#         2    0.005    0.002    0.005    0.002 <frozen importlib._bootstrap_external>:914(get_data)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        28    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.002    0.002 LASSOHelperAGTT.py:106(lambda_zero)
#         1    0.000    0.000   48.670   48.670 LASSOHelperAGTT.py:380(lasso_wrapper_parallel)
#        16    0.000    0.000    0.000    0.000 LASSOHelperAGTT.py:472(<genexpr>)
#        12    0.000    0.000    0.001    0.000 __init__.py:8(_make_name)
#        12    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#        16    0.000    0.000    0.000    0.000 _base.py:312(__init__)
#        77    0.000    0.000    0.000    0.000 _base.py:382(__get_result)
#        16    0.000    0.000    0.000    0.000 _base.py:388(add_done_callback)
#        77    0.001    0.000   48.417    0.629 _base.py:405(result)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:664(__contains__)
#         1    0.000    0.000    0.002    0.002 _memmapping_reducer.py:122(_get_temp_dir)
#         2    0.000    0.000    0.000    0.000 _memmapping_reducer.py:279(__init__)
#        16    0.000    0.000    0.000    0.000 _memmapping_reducer.py:288(__reduce__)
#         1    0.000    0.000    0.002    0.002 _memmapping_reducer.py:364(get_memmapping_reducers)
#         2    0.000    0.000    0.000    0.000 _memmapping_reducer.py:69(__init__)
#         3    0.000    0.000    0.000    0.000 _methods.py:134(_mean)
#         2    0.000    0.000    0.000    0.000 _methods.py:167(_var)
#         2    0.000    0.000    0.000    0.000 _methods.py:215(_std)
#         1    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         5    0.000    0.000    0.000    0.000 _methods.py:50(_count_reduce_items)
#        17    0.000    0.000    0.000    0.000 _parallel_backends.py:120(get_nested_backend)
#         2    0.000    0.000    0.000    0.000 _parallel_backends.py:133(retrieval_context)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:254(__init__)
#        17    0.000    0.000    0.000    0.000 _parallel_backends.py:258(compute_batch_size)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:321(reset_batch_stats)
#        17    0.000    0.000    0.000    0.000 _parallel_backends.py:36(__init__)
#         1    0.000    0.000    0.004    0.004 _parallel_backends.py:465(configure)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:480(effective_n_jobs)
#        16    0.000    0.000    0.239    0.015 _parallel_backends.py:508(apply_async)
#        77    0.000    0.000   48.417    0.629 _parallel_backends.py:516(wrap_future_result)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:525(terminate)
#        16    0.000    0.000    0.000    0.000 _parallel_backends.py:562(__init__)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:76(start_call)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:79(stop_call)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#         9    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        32    0.000    0.000    0.001    0.000 _win_reduction.py:25(__init__)
#        32    0.000    0.000    0.001    0.000 _win_reduction.py:52(reduce_pipe_connection)
#         8    0.000    0.000    0.000    0.000 cloudpickle.py:1164(_is_dynamic)
#         8    0.000    0.000    0.000    0.000 cloudpickle.py:176(islambda)
#         4    0.000    0.000    0.000    0.000 cloudpickle.py:242(_walk_global_ops)
#        16    0.000    0.000    0.000    0.000 cloudpickle.py:257(__init__)
#        16    0.000    0.000    0.046    0.003 cloudpickle.py:264(dump)
#         8    0.000    0.000    0.001    0.000 cloudpickle.py:286(save_module)
#         8    0.000    0.000    0.004    0.000 cloudpickle.py:298(save_codeobject)
#     64/40    0.000    0.000    0.012    0.000 cloudpickle.py:319(save_function)
#         8    0.000    0.000    0.000    0.000 cloudpickle.py:416(_save_subimports)
#         8    0.000    0.000    0.010    0.001 cloudpickle.py:540(save_function_tuple)
#         8    0.000    0.000    0.001    0.000 cloudpickle.py:603(extract_code_globals)
#         1    0.000    0.000    0.000    0.000 cloudpickle.py:616(<setcomp>)
#         8    0.000    0.000    0.001    0.000 cloudpickle.py:628(extract_func_data)
#   160/152    0.001    0.000    0.010    0.000 cloudpickle.py:678(save_global)
#         8    0.000    0.000    0.013    0.002 cloudpickle.py:712(save_instancemethod)
#        16    0.000    0.000    0.000    0.000 cloudpickle.py:898(inject_addons)
#         8    0.000    0.000    0.000    0.000 cloudpickle.py:905(is_tornado_coroutine)
#         6    0.000    0.000    0.000    0.000 connection.py:117(__init__)
#        48    0.000    0.000    0.000    0.000 connection.py:134(_check_closed)
#        16    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#        64    0.000    0.000    0.000    0.000 connection.py:158(readable)
#        64    0.000    0.000    0.000    0.000 connection.py:163(writable)
#        32    0.000    0.000    0.000    0.000 connection.py:168(fileno)
#        16    0.000    0.000    0.004    0.000 connection.py:181(send_bytes)
#        16    0.000    0.000    0.004    0.000 connection.py:279(_send_bytes)
#         3    0.000    0.000    0.001    0.000 connection.py:525(Pipe)
#         3    0.000    0.000    0.000    0.000 connection.py:69(arbitrary_address)
#         1    0.000    0.000    0.000    0.000 context.py:104(cpu_count)
#        13    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        13    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         1    0.000    0.000    0.000    0.000 context.py:212(_check_available)
#         2    0.000    0.000    0.000    0.000 context.py:232(get_context)
#       144    0.000    0.000    0.000    0.000 context.py:346(get_spawning_popen)
#        16    0.000    0.000    0.000    0.000 context.py:349(set_spawning_popen)
#         1    0.000    0.000    0.000    0.000 context.py:35(get_context)
#        56    0.000    0.000    0.000    0.000 context.py:352(assert_spawning)
#         2    0.000    0.000    0.000    0.000 context.py:40(cpu_count)
#         1    0.000    0.000    0.000    0.000 context.py:59(Pipe)
#         3    0.000    0.000    0.000    0.000 context.py:64(Lock)
#         9    0.000    0.000    0.001    0.000 context.py:84(BoundedSemaphore)
#         1    0.000    0.000    0.000    0.000 contextlib.py:107(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:116(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:237(helper)
#         1    0.000    0.000    0.000    0.000 contextlib.py:81(__init__)
#         2    0.000    0.000    0.000    0.000 copyreg.py:96(_slotnames)
#         1    0.000    0.000    0.000    0.000 dis.py:119(_get_code_object)
#         1    0.000    0.000    0.000    0.000 dis.py:251(get_instructions)
#         3    0.000    0.000    0.000    0.000 dis.py:273(_get_const_info)
#        14    0.000    0.000    0.000    0.000 dis.py:285(_get_name_info)
#        29    0.000    0.000    0.000    0.000 dis.py:301(_get_instructions_bytes)
#        58    0.000    0.000    0.000    0.000 dis.py:406(_unpack_opargs)
#         1    0.000    0.000    0.000    0.000 dis.py:417(findlabels)
#         5    0.000    0.000    0.000    0.000 dis.py:436(findlinestarts)
#         1    0.000    0.000    0.000    0.000 disk.py:104(delete_folder)
#         1    0.000    0.000    0.000    0.000 disk.py:41(memstr_to_bytes)
#         1    0.000    0.000    0.004    0.004 executor.py:20(get_memmapping_executor)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2092(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2232(_any_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2236(any)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2546(_amax_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2551(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:21(_linspace_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:26(linspace)
#        16    0.000    0.000    0.000    0.000 functools.py:37(update_wrapper)
#        16    0.000    0.000    0.000    0.000 functools.py:67(wraps)
#         8    0.000    0.000    0.000    0.000 gen.py:248(is_coroutine_function)
#         2    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         1    0.000    0.000    0.000    0.000 logger.py:23(_squeeze_time)
#         1    0.000    0.000    0.000    0.000 logger.py:39(short_format_time)
#         1    0.000    0.000    0.000    0.000 multiarray.py:635(result_type)
#        12    0.000    0.000    0.000    0.000 ntpath.py:122(splitdrive)
#         2    0.000    0.000    0.000    0.000 ntpath.py:287(expanduser)
#         1    0.000    0.000    0.000    0.000 ntpath.py:337(expandvars)
#         1    0.000    0.000    0.000    0.000 ntpath.py:34(_get_bothseps)
#         2    0.000    0.000    0.000    0.000 ntpath.py:450(normpath)
#         2    0.000    0.000    0.000    0.000 ntpath.py:523(abspath)
#         5    0.000    0.000    0.000    0.000 ntpath.py:75(join)
#         1    0.000    0.000    0.000    0.000 numeric.py:1786(isscalar)
#         9    0.000    0.000    0.000    0.000 os.py:673(__getitem__)
#         9    0.000    0.000    0.000    0.000 os.py:737(check_str)
#         9    0.000    0.000    0.000    0.000 os.py:743(encodekey)
#         3    0.000    0.000    0.000    0.000 os.py:769(getenv)
#        17    0.000    0.000    0.000    0.000 parallel.py:209(__init__)
#        49    0.000    0.000    0.000    0.000 parallel.py:227(__len__)
#        16    0.000    0.000    0.000    0.000 parallel.py:264(delayed)
#        16    0.000    0.000    0.000    0.000 parallel.py:274(delayed_function)
#        16    0.000    0.000    0.000    0.000 parallel.py:295(__init__)
#         1    0.000    0.000    0.000    0.000 parallel.py:584(__init__)
#         1    0.000    0.000    0.004    0.004 parallel.py:669(_initialize_backend)
#         1    0.000    0.000    0.000    0.000 parallel.py:694(_terminate_backend)
#        16    0.000    0.000    0.240    0.015 parallel.py:698(_dispatch)
#        17    0.000    0.000    0.240    0.014 parallel.py:735(dispatch_one_batch)
#         2    0.000    0.000    0.000    0.000 parallel.py:762(_print)
#         1    0.000    0.000    0.000    0.000 parallel.py:78(get_active_backend)
#         1    0.006    0.006   48.424   48.424 parallel.py:818(retrieve)
#         1    0.000    0.000   48.668   48.668 parallel.py:866(__call__)
#        16    0.000    0.000    0.000    0.000 pickle.py:189(__init__)
#        16    0.000    0.000    0.000    0.000 pickle.py:193(start_framing)
#        16    0.000    0.000    0.000    0.000 pickle.py:196(end_framing)
#      2544    0.002    0.000    0.003    0.000 pickle.py:201(commit_frame)
#      4536    0.003    0.000    0.004    0.000 pickle.py:225(write)
#       160    0.000    0.000    0.001    0.000 pickle.py:289(_getattribute)
#       225    0.000    0.000    0.000    0.000 pickle.py:302(whichmodule)
#        16    0.000    0.000    0.000    0.000 pickle.py:374(__init__)
#        16    0.000    0.000    0.046    0.003 pickle.py:426(dump)
#      1520    0.004    0.000    0.007    0.000 pickle.py:441(memoize)
#      1520    0.001    0.000    0.001    0.000 pickle.py:464(put)
#       336    0.000    0.000    0.001    0.000 pickle.py:476(get)
#   2528/16    0.010    0.000    0.045    0.003 pickle.py:485(save)
#      2528    0.000    0.000    0.000    0.000 pickle.py:551(persistent_id)
#     192/8    0.002    0.000    0.041    0.005 pickle.py:567(save_reduce)
#        88    0.000    0.000    0.000    0.000 pickle.py:669(save_none)
#       112    0.000    0.000    0.000    0.000 pickle.py:673(save_bool)
#       352    0.001    0.000    0.001    0.000 pickle.py:680(save_long)
#        32    0.000    0.000    0.000    0.000 pickle.py:718(save_bytes)
#       784    0.003    0.000    0.008    0.000 pickle.py:738(save_str)
#    328/32    0.001    0.000    0.035    0.001 pickle.py:758(save_tuple)
#        16    0.000    0.000    0.002    0.000 pickle.py:809(save_list)
#        16    0.000    0.000    0.002    0.000 pickle.py:822(_batch_appends)
#    136/16    0.000    0.000    0.044    0.003 pickle.py:849(save_dict)
#    136/16    0.002    0.000    0.044    0.003 pickle.py:862(_batch_setitems)
#       160    0.001    0.000    0.008    0.000 pickle.py:940(save_global)
#         1    0.000    0.000    0.002    0.002 popen_loky_win32.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 popen_loky_win32.py:38(Popen)
#         8    0.001    0.000    0.223    0.028 popen_loky_win32.py:44(__init__)
#        40    0.000    0.000    0.000    0.000 popen_loky_win32.py:55(<genexpr>)
#        40    0.000    0.000    0.001    0.000 popen_loky_win32.py:97(duplicate_for_child)
#        36    0.000    0.000    0.000    0.000 popen_spawn_win32.py:113(poll)
#        36    0.000    0.000    0.000    0.000 popen_spawn_win32.py:97(wait)
#         8    0.000    0.000    0.230    0.029 process.py:101(start)
#         8    0.000    0.000    0.000    0.000 process.py:17(__init__)
#         9    0.000    0.000    0.000    0.000 process.py:189(daemon)
#        16    0.000    0.000    0.000    0.000 process.py:204(authkey)
#         8    0.000    0.000    0.000    0.000 process.py:208(authkey)
#         8    0.000    0.000    0.000    0.000 process.py:225(ident)
#         8    0.000    0.000    0.000    0.000 process.py:250(__repr__)
#         8    0.000    0.000    0.230    0.029 process.py:31(_Popen)
#         8    0.000    0.000    0.000    0.000 process.py:326(__reduce__)
#        17    0.000    0.000    0.000    0.000 process.py:36(current_process)
#         8    0.000    0.000    0.000    0.000 process.py:53(_cleanup)
#         8    0.000    0.000    0.000    0.000 process.py:72(__init__)
#        16    0.000    0.000    0.000    0.000 process.py:85(<genexpr>)
#        16    0.000    0.000    0.000    0.000 process.py:90(_check_closed)
#        16    0.000    0.000    0.234    0.015 process_executor.py:1011(_ensure_executor_running)
#        16    0.000    0.000    0.239    0.015 process_executor.py:1019(submit)
#         1    0.000    0.000    0.000    0.000 process_executor.py:142(__init__)
#        16    0.000    0.000    0.004    0.000 process_executor.py:149(wakeup)
#         1    0.000    0.000    0.000    0.000 process_executor.py:169(__init__)
#        16    0.000    0.000    0.000    0.000 process_executor.py:244(__init__)
#         1    0.000    0.000    0.000    0.000 process_executor.py:281(__init__)
#         1    0.000    0.000    0.000    0.000 process_executor.py:764(_check_system_limits)
#         1    0.000    0.000    0.000    0.000 process_executor.py:800(_check_max_depth)
#         1    0.000    0.000    0.001    0.001 process_executor.py:854(__init__)
#         1    0.000    0.000    0.001    0.001 process_executor.py:930(_setup_queues)
#        16    0.000    0.000    0.002    0.000 process_executor.py:949(_start_queue_management_thread)
#         1    0.000    0.000    0.232    0.232 process_executor.py:992(_adjust_process_count)
#        16    0.000    0.000    0.000    0.000 queue.py:121(put)
#         1    0.000    0.000    0.000    0.000 queue.py:205(_init)
#        16    0.000    0.000    0.000    0.000 queue.py:212(_put)
#         1    0.000    0.000    0.000    0.000 queue.py:33(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:194(__init__)
#         8    0.000    0.000    0.000    0.000 queues.py:213(__getstate__)
#         1    0.000    0.000    0.000    0.000 queues.py:330(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:34(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:36(__init__)
#         8    0.000    0.000    0.000    0.000 queues.py:65(__getstate__)
#         1    0.000    0.000    0.000    0.000 queues.py:67(_after_fork)
#         1    0.000    0.000    0.000    0.000 random.py:174(randrange)
#         1    0.000    0.000    0.000    0.000 random.py:218(randint)
#       129    0.000    0.000    0.000    0.000 random.py:224(_randbelow)
#       128    0.000    0.000    0.000    0.000 random.py:256(choice)
#         2    0.000    0.000    0.000    0.000 random.py:88(__init__)
#         2    0.000    0.000    0.000    0.000 random.py:97(seed)
#        16    0.000    0.000    0.000    0.000 reduction.py:184(__init__)
#        16    0.000    0.000    0.047    0.003 reduction.py:233(dump)
#        40    0.000    0.000    0.000    0.000 reduction.py:71(duplicate)
#         1    0.000    0.000    0.001    0.001 reusable_executor.py:138(__init__)
#        16    0.000    0.000    0.239    0.015 reusable_executor.py:148(submit)
#         1    0.000    0.000    0.001    0.001 reusable_executor.py:200(_setup_queues)
#         1    0.000    0.000    0.000    0.000 reusable_executor.py:27(_get_next_executor_id)
#         1    0.000    0.000    0.001    0.001 reusable_executor.py:40(get_reusable_executor)
#         8    0.000    0.000    0.000    0.000 spawn.py:31(get_executable)
#         8    0.000    0.000    0.000    0.000 spawn.py:35(_check_not_importing_main)
#         8    0.000    0.000    0.000    0.000 spawn.py:53(get_preparation_data)
#         8    0.000    0.000    0.000    0.000 spawn.py:69(<listcomp>)
#         8    0.000    0.000    0.000    0.000 spawn.py:78(get_command_line)
#        24    0.000    0.000    0.000    0.000 spawn.py:87(<genexpr>)
#         1    0.000    0.000    0.000    0.000 spawn.py:9(<module>)
#         2    0.000    0.000    0.002    0.001 stats.py:2349(zscore)
#         2    0.000    0.000    0.000    0.000 stats.py:248(_contains_nan)
#         8    0.000    0.000    0.000    0.000 subprocess.py:246(_optim_args_from_interpreter_flags)
#         8    0.000    0.000    0.000    0.000 subprocess.py:256(_args_from_interpreter_flags)
#        40    0.000    0.000    0.001    0.000 synchronize.py:100(__getstate__)
#         9    0.000    0.000    0.001    0.000 synchronize.py:144(__init__)
#         3    0.000    0.000    0.000    0.000 synchronize.py:161(__init__)
#        12    0.000    0.000    0.001    0.000 synchronize.py:50(__init__)
#        12    0.000    0.000    0.000    0.000 synchronize.py:90(_make_methods)
#        16    0.000    0.000    0.000    0.000 synchronize.py:94(__enter__)
#        16    0.000    0.000    0.000    0.000 synchronize.py:97(__exit__)
#        16    0.000    0.000    0.000    0.000 tempfile.py:142(rng)
#        16    0.000    0.000    0.001    0.000 tempfile.py:153(__next__)
#        16    0.000    0.000    0.001    0.000 tempfile.py:156(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tempfile.py:159(_candidate_tempdir_list)
#         1    0.000    0.000    0.002    0.002 tempfile.py:186(_get_default_tempdir)
#         3    0.000    0.000    0.000    0.000 tempfile.py:233(_get_candidate_names)
#         1    0.000    0.000    0.002    0.002 tempfile.py:287(gettempdir)
#         3    0.000    0.000    0.000    0.000 tempfile.py:382(mktemp)
#         3    0.000    0.000    0.000    0.000 tempfile.py:84(_exists)
#         1    0.000    0.000    0.000    0.000 threading.py:1104(daemon)
#         1    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#         2    0.000    0.000    0.000    0.000 threading.py:1214(current_thread)
#        21    0.000    0.000    0.000    0.000 threading.py:216(__init__)
#       110    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#       110    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#        17    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#        53    0.001    0.000   48.418    0.914 threading.py:264(wait)
#        16    0.000    0.000    0.000    0.000 threading.py:335(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:499(__init__)
#         2    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#         1    0.000    0.000    0.002    0.002 threading.py:534(wait)
#        17    0.000    0.000    0.000    0.000 threading.py:75(RLock)
#         1    0.000    0.000    0.000    0.000 threading.py:758(__init__)
#         1    0.000    0.000    0.002    0.002 threading.py:829(start)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:44(_flip_dispatcher)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:99(flipud)
#         9    0.000    0.000    0.000    0.000 util.py:151(__init__)
#        17    0.000    0.000    0.000    0.000 util.py:48(debug)
#         2    0.000    0.000    0.000    0.000 weakref.py:408(__setitem__)
#         8    0.000    0.000    0.000    0.000 weakref.py:432(get)
#        28    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFD35EF6BA0}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#        10    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#        10    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#      1536    0.001    0.000    0.001    0.000 {built-in method _struct.pack}
#        61    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         6    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        40    0.000    0.000    0.000    0.000 {built-in method _winapi.CloseHandle}
#         3    0.000    0.000    0.000    0.000 {built-in method _winapi.ConnectNamedPipe}
#         3    0.000    0.000    0.000    0.000 {built-in method _winapi.CreateFile}
#         3    0.000    0.000    0.000    0.000 {built-in method _winapi.CreateNamedPipe}
#         8    0.000    0.000    0.000    0.000 {built-in method _winapi.CreatePipe}
#         8    0.174    0.022    0.174    0.022 {built-in method _winapi.CreateProcess}
#        72    0.001    0.000    0.001    0.000 {built-in method _winapi.DuplicateHandle}
#        72    0.000    0.000    0.000    0.000 {built-in method _winapi.GetCurrentProcess}
#        32    0.000    0.000    0.000    0.000 {built-in method _winapi.OpenProcess}
#         3    0.000    0.000    0.000    0.000 {built-in method _winapi.SetNamedPipeHandleState}
#        36    0.000    0.000    0.000    0.000 {built-in method _winapi.WaitForSingleObject}
#        16    0.003    0.000    0.003    0.000 {built-in method _winapi.WriteFile}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#       161    0.001    0.000    0.002    0.000 {built-in method builtins.__import__}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       193    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.eval}
#       3/1    0.000    0.000   48.670   48.670 {built-in method builtins.exec}
#      1530    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#       243    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#      5976    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       586    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       138    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       153    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      3269    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#        41    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        38    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        82    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         6    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         9    0.000    0.000    0.000    0.000 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         8    0.000    0.000    0.000    0.000 {built-in method msvcrt.open_osfhandle}
#         2    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._isdir}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.close}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.cpu_count}
#        28    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         9    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#       106    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.lstat}
#         1    0.001    0.001    0.001    0.001 {built-in method nt.open}
#         8    0.001    0.000    0.001    0.000 {built-in method nt.stat}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.unlink}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       8/5    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        18    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {function Random.seed at 0x00000271974EEEA0}
#        19    0.000    0.000    0.000    0.000 {method 'GetOverlappedResult' of '_winapi.Overlapped' objects}
#        16    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#        93    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#        17    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        16    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#        93    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        17    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       120    0.001    0.000    0.002    0.000 {method '__reduce_ex__' of 'object' objects}
#        52    0.000    0.000    0.000    0.000 {method '_acquire_restore' of '_thread.RLock' objects}
#        52    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#        52    0.000    0.000    0.000    0.000 {method '_release_save' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       126   48.417    0.384   48.417    0.384 {method 'acquire' of '_thread.lock' objects}
#        17    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#        69    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        22    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       129    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        24    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       784    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        78    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#     36/20    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#      5081    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        16    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#       220    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         8    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       172    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        56    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        77    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'read' of '_io.FileIO' objects}
#        12    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        11    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       190    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       162    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'std' of 'numpy.ndarray' objects}
#      2560    0.001    0.000    0.001    0.000 {method 'tell' of '_io.BytesIO' objects}
#        24    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        49    0.000    0.000    0.000    0.000 {method 'write' of '_io.BufferedWriter' objects}
#      4520    0.001    0.000    0.001    0.000 {method 'write' of '_io.BytesIO' objects}

# %% [markdown]
# The following table shows the relative time taken to compute the $\lambda$ that minimizes the objective function, under three wrapping strategies.
#
# | Wrapper Function | Sequential + Same IC | Sequential + Warm Start | Parallel |
# |:----------------:|:--------------------:|:-----------------------:|:--------:|
# |   Relative Time  |           1          |          0.9415         |  0.3007  |
#
# The parallel strategy is the fastest, and is employed in the K-fold cross-validation algorithm below.
#
# ### Part G: K-Fold Cross-Validation

# %%
output_CV, lambda_CV, lasso_CV  = lasso_wrapper_parallel(b_start=np.zeros([N_param, 1]), y=Y, X=X, standardized=False, num_lambda=100, min_factor=0.0001, k_fold=True)

# %% [markdown]
# We have added the figure corresponding to a plot of the penalties versus the CV errors (`Q1_CV.PNG`) in the ZIP file.
